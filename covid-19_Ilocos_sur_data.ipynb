# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style(style="darkgrid")# "whitegrid")
# %matplotlib inline

# %%
df_group = pd.read_csv('Case Information_batch_3.csv')

# %%
df_group
# Out:
#          CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease  \
# 0       C46369460  23.0  20 to 24    MALE   2022-01-07        2022-01-08
# 1       C69025406   7.0    5 to 9  FEMALE   2022-01-06        2022-01-08
# 2        C6572422  27.0  25 to 29  FEMALE   2022-01-06        2022-01-08
# 3       C16040871  17.0  15 to 19  FEMALE   2022-01-08        2022-01-09
# 4       C66405262  41.0  40 to 44    MALE   2022-01-08        2022-01-09
# ...           ...   ...       ...     ...          ...               ...
# 387519  C32778890  50.0  50 to 54    MALE   2022-01-19        2022-01-19
# 387520  C28728958  36.0  35 to 39    MALE   2022-01-13        2022-01-14
# 387521  C95368764  37.0  35 to 39    MALE   2022-01-19        2022-01-20
# 387522  C59216411  10.0  10 to 14  FEMALE   2022-01-17        2022-01-20
# 387523  C77787290  38.0  35 to 39  FEMALE   2022-01-19        2022-01-20
#
#        DateRepConf DateDied DateRecover RemovalType  ...   ProvRes  \
# ...

# %%
df_group = df_group.set_index("CaseCode")
df_group.head()
# Out:
#             Age  AgeGroup     Sex DateSpecimen DateResultRelease DateRepConf  \
# CaseCode
# C46369460  23.0  20 to 24    MALE   2022-01-07        2022-01-08  2022-01-11
# C69025406   7.0    5 to 9  FEMALE   2022-01-06        2022-01-08  2022-01-11
# C6572422   27.0  25 to 29  FEMALE   2022-01-06        2022-01-08  2022-01-11
# C16040871  17.0  15 to 19  FEMALE   2022-01-08        2022-01-09  2022-01-11
# C66405262  41.0  40 to 44    MALE   2022-01-08        2022-01-09  2022-01-11
#
#           DateDied DateRecover RemovalType Admitted  ...   ProvRes  \
# CaseCode                                             ...
# C46369460      NaN         NaN   RECOVERED      NaN  ...       NCR
# C69025406      NaN         NaN   RECOVERED      NaN  ...     RIZAL
# C6572422       NaN         NaN   RECOVERED      NaN  ...  PAMPANGA
# C16040871      NaN         NaN   RECOVERED      NaN  ...      CEBU
# C66405262      NaN         NaN   RECOVERED      NaN  ...       NCR
#
# ...

# %%
(df_group[df_group['ProvRes'] == 'ILOCOS SUR'])
# Out:
#             Age  AgeGroup     Sex DateSpecimen DateResultRelease DateRepConf  \
# CaseCode
# C1262675   26.0  25 to 29    MALE   2022-01-08        2022-01-10  2022-01-11
# C43874335  45.0  45 to 49  FEMALE   2022-01-07        2022-01-08  2022-01-11
# C40740561  37.0  35 to 39  FEMALE   2022-01-07        2022-01-08  2022-01-11
# C87078322  21.0  20 to 24  FEMALE   2022-01-09        2022-01-10  2022-01-11
# C39174719  24.0  20 to 24  FEMALE   2022-01-03        2022-01-07  2022-01-11
# ...         ...       ...     ...          ...               ...         ...
# C58249797  27.0  25 to 29  FEMALE   2022-01-19        2022-01-21  2022-01-22
# C92173719  18.0  15 to 19  FEMALE   2022-01-18        2022-01-19  2022-01-22
# C9516291   26.0  25 to 29  FEMALE   2022-01-18        2022-01-19  2022-01-22
# C11348288  54.0  50 to 54    MALE   2022-01-19        2022-01-20  2022-01-22
# C18439871   1.0    0 to 4  FEMALE   2022-01-19        2022-01-20  2022-01-22
#
# ...

# %%
y = targets = labels = output_var = df_group["RemovalType"]
x = predictors = input_var = df_group.loc[:,df_group.columns != "RemovalType"]

# %%
y.head()
# Out:
# CaseCode
# C46369460    RECOVERED
# C69025406    RECOVERED
# C6572422     RECOVERED
# C16040871    RECOVERED
# C66405262    RECOVERED
# Name: RemovalType, dtype: object

# %%
x.head()
# Out:
#             Age  AgeGroup     Sex DateSpecimen DateResultRelease DateRepConf  \
# CaseCode
# C46369460  23.0  20 to 24    MALE   2022-01-07        2022-01-08  2022-01-11
# C69025406   7.0    5 to 9  FEMALE   2022-01-06        2022-01-08  2022-01-11
# C6572422   27.0  25 to 29  FEMALE   2022-01-06        2022-01-08  2022-01-11
# C16040871  17.0  15 to 19  FEMALE   2022-01-08        2022-01-09  2022-01-11
# C66405262  41.0  40 to 44    MALE   2022-01-08        2022-01-09  2022-01-11
#
#           DateDied DateRecover Admitted                    RegionRes  \
# CaseCode
# C46369460      NaN         NaN      NaN                          NCR
# C69025406      NaN         NaN      NaN      Region IV-A: CALABARZON
# C6572422       NaN         NaN      NaN    Region III: Central Luzon
# C16040871      NaN         NaN      NaN  Region VII: Central Visayas
# C66405262      NaN         NaN      NaN                          NCR
#
# ...
